# %% [markdown]
# # Mandatory Challenge
# ## Context
# You work in the data analysis team of a very important company. On Monday, the company shares some good news with you: you just got hired by a major retail company! So, let's get prepared for a huge amount of work!
#
# Then you get to work with your team and define the following tasks to perform:
# 1. You need to start your analysis using data from the past.
# 2. You need to define a process that takes your daily data as an input and integrates it.
#
# You are in charge of the second part, so you are provided with a sample file that you will have to read daily. To complete you task, you need the following aggregates:
# * One aggregate per store that adds up the rest of the values.
# * One aggregate per item that adds up the rest of the values.
#
# You can import the dataset `warehouse_and_retail_sales` from Ironhack's database.
#
# ## Your task
# Therefore, your process will consist of the following steps:
# 1. Read the sample file that a daily process will save in your folder.
# 2. Clean up the data.
# 3. Create the aggregates.
# 4. Write three tables in your local database:
#     - A table for the cleaned data.
#     - A table for the aggregate per supplier.
#     - A table for the aggregate per item.
#
# ## Instructions
# * Read the csv you can find in Ironhack's database.
# * Clean the data and create the aggregates as you consider.
# * Create the tables in your local database.
# * Populate them with your process.

# %%
# your code here

import pandas as pd
import numpy as np

# %%
# Creamos el DataFrame y lo visualizamos
df = pd.read_csv('Warehouse_and_Retail_Sales_20240205.csv')

df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                               BOOTLEG RED - 750ML      WINE          0.00
# 1                         MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2               S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3                     SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4                    SANTORINI GAVALA WHITE - 750ML      WINE          0.82
# ...                                             ...       ...           ...
# 307640  ST PETERS ORGANIC ENG ALE NR 12/CS - 16.9OZ      BEER          0.00
# 307641               STELLA ARTOIS 2/12 NR - 11.2OZ      BEER        372.45
# 307642                       TECATE 4/6 LNNR - 12OZ      BEER          7.79
# 307643     S SMITH WINTER WELCOME NR 12/CS - 18.7OZ      BEER          0.00
# 307644          S SMITH WINTER WELCOME 4/6NR - 12OZ      BEER          0.00
#
#         RETAIL TRANSFERS  WAREHOUSE SALES
# 0                    0.0             2.00
# 1                    1.0             4.00
# 2                    0.0             1.00
# 3                    0.0             1.00
# 4                    0.0             0.00
# ...                  ...              ...
# 307640               0.0             1.00
# 307641             315.0          3586.88
# 307642               0.0             4.00
# 307643               0.0             2.00
# 307644               0.0             1.00
#
# [307645 rows x 9 columns]

# %%
# Comprobamos si hay datos nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307645 entries, 0 to 307644
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   YEAR              307645 non-null  int64
#  1   MONTH             307645 non-null  int64
#  2   SUPPLIER          307478 non-null  object
#  3   ITEM CODE         307645 non-null  object
#  4   ITEM DESCRIPTION  307645 non-null  object
#  5   ITEM TYPE         307644 non-null  object
#  6   RETAIL SALES      307642 non-null  float64
#  7   RETAIL TRANSFERS  307645 non-null  float64
#  8   WAREHOUSE SALES   307645 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 21.1+ MB

# %%
nan_cols = df.isna().sum() / df.shape[0]*100

# %%
nan_cols[nan_cols>0]
# Out:
# SUPPLIER        0.054283
# ITEM TYPE       0.000325
# RETAIL SALES    0.000975
# dtype: float64

# %%
df.shape
# Out:
# (307645, 9)

# %%
nan_df = df[(df.SUPPLIER.isna())|(df['ITEM TYPE'].isna()) | (df['RETAIL SALES'].isna())]

# %%
nan_df.head()
# Out:
#      YEAR  MONTH SUPPLIER ITEM CODE           ITEM DESCRIPTION     ITEM TYPE  \
# 106  2020      1      NaN       107  JIGGER MEASURE SHOT GLASS  STR_SUPPLIES
# 188  2020      1      NaN       113     BARTENDERS BLACK  BOOK  STR_SUPPLIES
# 231  2020      1      NaN       115    PLASTIC SHOT GLASS PACK  STR_SUPPLIES
# 252  2020      1      NaN       117    WHISKEY TASTING JOURNAL  STR_SUPPLIES
# 261  2020      1      NaN       118    PLASTIC WINE GLASS PACK  STR_SUPPLIES
#
#      RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES
# 106         14.69              18.0              0.0
# 188          0.40               0.0              0.0
# 231          5.71               6.0              0.0
# 252          0.08               0.0              0.0
# 261          7.40              10.0              0.0

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (307477, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 307477 entries, 0 to 307644
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   YEAR              307477 non-null  int64
#  1   MONTH             307477 non-null  int64
#  2   SUPPLIER          307477 non-null  object
#  3   ITEM CODE         307477 non-null  object
#  4   ITEM DESCRIPTION  307477 non-null  object
#  5   ITEM TYPE         307477 non-null  object
#  6   RETAIL SALES      307477 non-null  float64
#  7   RETAIL TRANSFERS  307477 non-null  float64
#  8   WAREHOUSE SALES   307477 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 23.5+ MB

# %%
nan_df.head()
# Out:
#      YEAR  MONTH SUPPLIER ITEM CODE           ITEM DESCRIPTION     ITEM TYPE  \
# 106  2020      1      NaN       107  JIGGER MEASURE SHOT GLASS  STR_SUPPLIES
# 188  2020      1      NaN       113     BARTENDERS BLACK  BOOK  STR_SUPPLIES
# 231  2020      1      NaN       115    PLASTIC SHOT GLASS PACK  STR_SUPPLIES
# 252  2020      1      NaN       117    WHISKEY TASTING JOURNAL  STR_SUPPLIES
# 261  2020      1      NaN       118    PLASTIC WINE GLASS PACK  STR_SUPPLIES
#
#      RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES
# 106         14.69              18.0              0.0
# 188          0.40               0.0              0.0
# 231          5.71               6.0              0.0
# 252          0.08               0.0              0.0
# 261          7.40              10.0              0.0

# %%
df.groupby('SUPPLIER')

# %%
df.groupby('SUPPLIER').sum().head()
# Out:
#                            YEAR  MONTH  \
# SUPPLIER
# 8 VINI INC                18154     74
# A HARDY USA LTD            8068     33
# A I G WINE & SPIRITS     143285    450
# A VINTNERS SELECTIONS  20162849  65284
# A&E INC                   84732    311
#
#                                                                ITEM CODE  \
# SUPPLIER
# 8 VINI INC             3313483313483313483313483283823313483313483313...
# A HARDY USA LTD                                     44262442624426244262
# A I G WINE & SPIRITS   1192291202003354521192291202003354521192291202...
# A VINTNERS SELECTIONS  1487171015321015671030551036081056511086341087...
# A&E INC                3118433126453130433387524628931264531304331184...
#
#                                                         ITEM DESCRIPTION  \
# SUPPLIER
# 8 VINI INC             SECOLI RIPASSO DELIO VAL DOC - 750MLSECOLI RIP...
# A HARDY USA LTD        BUNRATTY POTCHEEN GLASS - 750MLBUNRATTY POTCHE...
# A I G WINE & SPIRITS   TROCADERO SPARK(BRUT) - 750MLDOM DES FONTANELL...
# A VINTNERS SELECTIONS  YAEGAKI SAKE - 18LHATSUMAGO SAKE JUN MAI SHU -...
# A&E INC                ORLANDO ABRIGO BARBERA D'ALBA - 750MLVILLA VIS...
#
#                                                                ITEM TYPE  \
# SUPPLIER
# 8 VINI INC                          WINEWINEWINEWINEWINEWINEWINEWINEWINE
# A HARDY USA LTD                                 LIQUORLIQUORLIQUORLIQUOR
# A I G WINE & SPIRITS   WINEWINEWINEWINEWINEWINEWINEWINEWINEWINEWINELI...
# A VINTNERS SELECTIONS  WINEWINEWINEWINEWINEWINEWINELIQUORWINEWINEWINE...
# A&E INC                WINEWINEWINEWINEWINEWINEWINEWINEWINEWINEWINEWI...
#
#                        RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES
# SUPPLIER
# 8 VINI INC                     2.53              2.00             1.00
# A HARDY USA LTD                0.56              0.00             0.00
# A I G WINE & SPIRITS          13.24              4.92           197.00
# A VINTNERS SELECTIONS       9482.87           8238.29         35241.97
# A&E INC                       11.49              0.08             0.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 307477 entries, 0 to 307644
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   YEAR              307477 non-null  int64
#  1   MONTH             307477 non-null  int64
#  2   SUPPLIER          307477 non-null  object
#  3   ITEM CODE         307477 non-null  object
#  4   ITEM DESCRIPTION  307477 non-null  object
#  5   ITEM TYPE         307477 non-null  object
#  6   RETAIL SALES      307477 non-null  float64
#  7   RETAIL TRANSFERS  307477 non-null  float64
#  8   WAREHOUSE SALES   307477 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 23.5+ MB

# %%
df.groupby('SUPPLIER').mean(numeric_only=True).head()
# Out:
#                               YEAR     MONTH  RETAIL SALES  RETAIL TRANSFERS  \
# SUPPLIER
# 8 VINI INC             2017.111111  8.222222      0.281111          0.222222
# A HARDY USA LTD        2017.000000  8.250000      0.140000          0.000000
# A I G WINE & SPIRITS   2018.098592  6.338028      0.186479          0.069296
# A VINTNERS SELECTIONS  2017.495397  6.532319      0.948856          0.824324
# A&E INC                2017.428571  7.404762      0.273571          0.001905
#
#                        WAREHOUSE SALES
# SUPPLIER
# 8 VINI INC                    0.111111
# A HARDY USA LTD               0.000000
# A I G WINE & SPIRITS          2.774648
# A VINTNERS SELECTIONS         3.526313
# A&E INC                       0.000000

# %%
df._get_numeric_data().head()
# Out:
#    YEAR  MONTH  RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES
# 0  2020      1          0.00               0.0              2.0
# 1  2020      1          0.00               1.0              4.0
# 2  2020      1          0.00               0.0              1.0
# 3  2020      1          0.00               0.0              1.0
# 4  2020      1          0.82               0.0              0.0

# %%
df.select_dtypes('number').head()
# Out:
#    YEAR  MONTH  RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES
# 0  2020      1          0.00               0.0              2.0
# 1  2020      1          0.00               1.0              4.0
# 2  2020      1          0.00               0.0              1.0
# 3  2020      1          0.00               0.0              1.0
# 4  2020      1          0.82               0.0              0.0

# %%
df.select_dtypes('object').head()
# Out:
#                             SUPPLIER ITEM CODE  \
# 0  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1                          PWSWN INC    100024
# 2            RELIABLE CHURCHILL LLLP      1001
# 3          LANTERNA DISTRIBUTORS INC    100145
# 4               DIONYSOS IMPORTS INC    100293
#
#                       ITEM DESCRIPTION ITEM TYPE
# 0                  BOOTLEG RED - 750ML      WINE
# 1            MOMENT DE PLAISIR - 750ML      WINE
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER
# 3        SCHLINK HAUS KABINETT - 750ML      WINE
# 4       SANTORINI GAVALA WHITE - 750ML      WINE

# %%
df.describe().T
# Out:
#                      count         mean         std      min     25%      50%  \
# YEAR              307477.0  2018.438238    1.083080  2017.00  2017.0  2019.00
# MONTH             307477.0     6.424064    3.461853     1.00     3.0     7.00
# RETAIL SALES      307477.0     7.003644   30.387012    -6.49     0.0     0.32
# RETAIL TRANSFERS  307477.0     6.938177   30.244239   -38.49     0.0     0.00
# WAREHOUSE SALES   307477.0    25.375561  249.500572 -4996.00     0.0     1.00
#
#                       75%       max
# YEAR              2019.00   2020.00
# MONTH                9.00     12.00
# RETAIL SALES         3.26   1816.49
# RETAIL TRANSFERS     3.00   1990.83
# WAREHOUSE SALES      5.00  18317.00

# %%
df.describe(include='object').T
# Out:
#                    count unique                                top    freq
# SUPPLIER          307477    396  REPUBLIC NATIONAL DISTRIBUTING CO   20994
# ITEM CODE         307477  34039                              81321      24
# ITEM DESCRIPTION  307477  34805           BURGANS ALBARINO - 750ML      44
# ITEM TYPE         307477      8                               WINE  187640

# %%
df['ITEM CODE'][0]
# Out:
# '100009'

# %%
df.groupby('SUPPLIER').mean(numeric_only=True).head()
# Out:
#                               YEAR     MONTH  RETAIL SALES  RETAIL TRANSFERS  \
# SUPPLIER
# 8 VINI INC             2017.111111  8.222222      0.281111          0.222222
# A HARDY USA LTD        2017.000000  8.250000      0.140000          0.000000
# A I G WINE & SPIRITS   2018.098592  6.338028      0.186479          0.069296
# A VINTNERS SELECTIONS  2017.495397  6.532319      0.948856          0.824324
# A&E INC                2017.428571  7.404762      0.273571          0.001905
#
#                        WAREHOUSE SALES
# SUPPLIER
# 8 VINI INC                    0.111111
# A HARDY USA LTD               0.000000
# A I G WINE & SPIRITS          2.774648
# A VINTNERS SELECTIONS         3.526313
# A&E INC                       0.000000

# %%
df.groupby('SUPPLIER').sum(numeric_only=False).head()
# Out:
#                            YEAR  MONTH  \
# SUPPLIER
# 8 VINI INC                18154     74
# A HARDY USA LTD            8068     33
# A I G WINE & SPIRITS     143285    450
# A VINTNERS SELECTIONS  20162849  65284
# A&E INC                   84732    311
#
#                                                                ITEM CODE  \
# SUPPLIER
# 8 VINI INC             3313483313483313483313483283823313483313483313...
# A HARDY USA LTD                                     44262442624426244262
# A I G WINE & SPIRITS   1192291202003354521192291202003354521192291202...
# A VINTNERS SELECTIONS  1487171015321015671030551036081056511086341087...
# A&E INC                3118433126453130433387524628931264531304331184...
#
#                                                         ITEM DESCRIPTION  \
# SUPPLIER
# 8 VINI INC             SECOLI RIPASSO DELIO VAL DOC - 750MLSECOLI RIP...
# A HARDY USA LTD        BUNRATTY POTCHEEN GLASS - 750MLBUNRATTY POTCHE...
# A I G WINE & SPIRITS   TROCADERO SPARK(BRUT) - 750MLDOM DES FONTANELL...
# A VINTNERS SELECTIONS  YAEGAKI SAKE - 18LHATSUMAGO SAKE JUN MAI SHU -...
# A&E INC                ORLANDO ABRIGO BARBERA D'ALBA - 750MLVILLA VIS...
#
#                                                                ITEM TYPE  \
# SUPPLIER
# 8 VINI INC                          WINEWINEWINEWINEWINEWINEWINEWINEWINE
# A HARDY USA LTD                                 LIQUORLIQUORLIQUORLIQUOR
# A I G WINE & SPIRITS   WINEWINEWINEWINEWINEWINEWINEWINEWINEWINEWINELI...
# A VINTNERS SELECTIONS  WINEWINEWINEWINEWINEWINEWINELIQUORWINEWINEWINE...
# A&E INC                WINEWINEWINEWINEWINEWINEWINEWINEWINEWINEWINEWI...
#
#                        RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES
# SUPPLIER
# 8 VINI INC                     2.53              2.00             1.00
# A HARDY USA LTD                0.56              0.00             0.00
# A I G WINE & SPIRITS          13.24              4.92           197.00
# A VINTNERS SELECTIONS       9482.87           8238.29         35241.97
# A&E INC                       11.49              0.08             0.00

# %%
grupo_supplier = df.groupby('SUPPLIER').agg({'YEAR': 'max', 
                            'MONTH': 'min', 
                            'ITEM CODE': 'first', 
                            'ITEM DESCRIPTION': 'last',
                            'ITEM TYPE': 'max', 
                            'RETAIL SALES': 'mean', 
                            'RETAIL TRANSFERS':'mean', 
                            'WAREHOUSE SALES': 'mean'})

# %%
grupo_supplier
# Out:
#                              YEAR  MONTH ITEM CODE  \
# SUPPLIER
# 8 VINI INC                   2018      1    331348
# A HARDY USA LTD              2017      6     44262
# A I G WINE & SPIRITS         2020      1    119229
# A VINTNERS SELECTIONS        2019      1    148717
# A&E INC                      2019      1    311843
# ...                           ...    ...       ...
# WITH MALUS AFORETHOUGHT LLC  2020      9    356900
# YOUNG WON TRADING INC        2020      1     10345
# YUENGLING BREWERY            2020      1     23733
# Z WINE GALLERY IMPORTS LLC   2020      1    332104
# ZURENA LLC                   2020      1    300614
#
#                                                             ITEM DESCRIPTION  \
# SUPPLIER
# 8 VINI INC                              SECOLI RIPASSO DELIO VAL DOC - 750ML
# A HARDY USA LTD                              BUNRATTY POTCHEEN GLASS - 750ML
# A I G WINE & SPIRITS                        DOM DES FONTANELLE S/BLC - 750ML
# A VINTNERS SELECTIONS                                     ROOT 1 CAB - 750ML
# A&E INC                        TENUTE RUBINO SUSUMANIELLO OLTREME 13 - 750ML
# ...                                                                      ...
# WITH MALUS AFORETHOUGHT LLC                          LIFE'S A PEACH 6/4 CANS
# YOUNG WON TRADING INC                         HAKUSHIKA JUNMAI GINJO - 900ML
# YUENGLING BREWERY                                       YUENGLING LAGER 1/2K
# Z WINE GALLERY IMPORTS LLC                       ALAIN GEOFFREY CHAB - 750ML
# ZURENA LLC                   ZURENA LOVE ELIXIR CRAFT COCKTAIL MIXER - 750ML
#
#                                ITEM TYPE  RETAIL SALES  RETAIL TRANSFERS  \
# SUPPLIER
# 8 VINI INC                          WINE      0.281111          0.222222
# A HARDY USA LTD                   LIQUOR      0.140000          0.000000
# A I G WINE & SPIRITS                WINE      0.186479          0.069296
# A VINTNERS SELECTIONS               WINE      0.948856          0.824324
# A&E INC                             WINE      0.273571          0.001905
# ...                                  ...           ...               ...
# WITH MALUS AFORETHOUGHT LLC         BEER      0.000000          0.000000
# YOUNG WON TRADING INC               WINE      1.733575          1.693499
# YUENGLING BREWERY                   KEGS     50.169281         48.806383
# Z WINE GALLERY IMPORTS LLC          WINE      0.440909          0.414773
# ZURENA LLC                   NON-ALCOHOL      1.360000          0.985652
#
#                              WAREHOUSE SALES
# SUPPLIER
# 8 VINI INC                          0.111111
# A HARDY USA LTD                     0.000000
# A I G WINE & SPIRITS                2.774648
# A VINTNERS SELECTIONS               3.526313
# A&E INC                             0.000000
# ...                                      ...
# WITH MALUS AFORETHOUGHT LLC         7.500000
# YOUNG WON TRADING INC               3.627084
# YUENGLING BREWERY                 292.261133
# Z WINE GALLERY IMPORTS LLC          0.681818
# ZURENA LLC                          0.000000
#
# [396 rows x 8 columns]

# %%
grupo_supplier = grupo_supplier.reset_index()

# %%
grupo_supplier.head()
# Out:
#                 SUPPLIER  YEAR  MONTH ITEM CODE  \
# 0             8 VINI INC  2018      1    331348
# 1        A HARDY USA LTD  2017      6     44262
# 2   A I G WINE & SPIRITS  2020      1    119229
# 3  A VINTNERS SELECTIONS  2019      1    148717
# 4                A&E INC  2019      1    311843
#
#                                 ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0           SECOLI RIPASSO DELIO VAL DOC - 750ML      WINE      0.281111
# 1                BUNRATTY POTCHEEN GLASS - 750ML    LIQUOR      0.140000
# 2               DOM DES FONTANELLE S/BLC - 750ML      WINE      0.186479
# 3                             ROOT 1 CAB - 750ML      WINE      0.948856
# 4  TENUTE RUBINO SUSUMANIELLO OLTREME 13 - 750ML      WINE      0.273571
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0          0.222222         0.111111
# 1          0.000000         0.000000
# 2          0.069296         2.774648
# 3          0.824324         3.526313
# 4          0.001905         0.000000

# %%
grupo_supplier_2 = df.groupby('SUPPLIER').agg({'RETAIL SALES': ['min', 'mean', 'std', 'max']}).head()

# %%
grupo_supplier_2
# Out:
#                       RETAIL SALES
#                                min      mean       std    max
# SUPPLIER
# 8 VINI INC                    0.00  0.281111  0.340971   1.07
# A HARDY USA LTD               0.08  0.140000  0.040000   0.16
# A I G WINE & SPIRITS          0.00  0.186479  0.340676   1.67
# A VINTNERS SELECTIONS        -1.84  0.948856  3.280589  80.88
# A&E INC                       0.00  0.273571  0.276933   1.41

# %%
grupo_supplier_2.columns
# Out:
# MultiIndex([('RETAIL SALES',  'min'),
#             ('RETAIL SALES', 'mean'),
#             ('RETAIL SALES',  'std'),
#             ('RETAIL SALES',  'max')],
#            )

# %%
grupo_supplier_2[('RETAIL SALES', 'mean')]
# Out:
# SUPPLIER
# 8 VINI INC               0.281111
# A HARDY USA LTD          0.140000
# A I G WINE & SPIRITS     0.186479
# A VINTNERS SELECTIONS    0.948856
# A&E INC                  0.273571
# Name: (RETAIL SALES, mean), dtype: float64

# %%
df.head()['ITEM TYPE'].to_list()
# Out:
# ['WINE', 'WINE', 'BEER', 'WINE', 'WINE']

# %%
def moda(lst):
    
    lst = lst.to_list()
    
    letra = ''
    
    num = 0
    
    for e in lst:
        
        if lst.count(e) > num:
            
            letra = e
            num = lst.count(e)
        
    
    return letra

# %%
df.groupby('SUPPLIER').agg({'ITEM TYPE': moda}).head()
# Out:
#                       ITEM TYPE
# SUPPLIER
# 8 VINI INC                 WINE
# A HARDY USA LTD          LIQUOR
# A I G WINE & SPIRITS       WINE
# A VINTNERS SELECTIONS      WINE
# A&E INC                    WINE

# %%
grupo_supplier_2.reset_index().to_csv('supplier_group.csv')

# %%
pd.read_csv('supplier_group.csv')
# Out:
#    Unnamed: 0               SUPPLIER RETAIL SALES       RETAIL SALES.1  \
# 0         NaN                    NaN          min                 mean
# 1         0.0             8 VINI INC          0.0  0.28111111111111114
# 2         1.0        A HARDY USA LTD         0.08                 0.14
# 3         2.0   A I G WINE & SPIRITS          0.0  0.18647887323943663
# 4         3.0  A VINTNERS SELECTIONS        -1.84   0.9488563137882731
# 5         4.0                A&E INC          0.0   0.2735714285714286
#
#         RETAIL SALES.2 RETAIL SALES.3
# 0                  std            max
# 1   0.3409708361592104           1.07
# 2  0.04000000000000001           0.16
# 3   0.3406762123925603           1.67
# 4   3.2805886859304656          80.88
# 5  0.27693286523395866           1.41

# %%
pd.read_csv('supplier_group.csv').to_csv('supplier_group.csv')

# %%
pd.read_csv('supplier_group.csv')
# Out:
#    Unnamed: 0.1  Unnamed: 0               SUPPLIER RETAIL SALES  \
# 0             0         NaN                    NaN          min
# 1             1         0.0             8 VINI INC          0.0
# 2             2         1.0        A HARDY USA LTD         0.08
# 3             3         2.0   A I G WINE & SPIRITS          0.0
# 4             4         3.0  A VINTNERS SELECTIONS        -1.84
# 5             5         4.0                A&E INC          0.0
#
#         RETAIL SALES.1       RETAIL SALES.2 RETAIL SALES.3
# 0                 mean                  std            max
# 1  0.28111111111111114   0.3409708361592104           1.07
# 2                 0.14  0.04000000000000001           0.16
# 3  0.18647887323943663   0.3406762123925603           1.67
# 4   0.9488563137882731   3.2805886859304656          80.88
# 5   0.2735714285714286  0.27693286523395866           1.41

# %%
df.groupby('ITEM TYPE')

# %%
df.groupby('ITEM TYPE').sum(numeric_only=True)
# Out:
#                    YEAR    MONTH  RETAIL SALES  RETAIL TRANSFERS  \
# ITEM TYPE
# BEER           85610635   270898     574220.53         566714.00
# DUNNAGE          145332      456          0.00              0.00
# KEGS           20478724    64836          0.00             -1.00
# LIQUOR        131015604   414463     802691.43         794735.71
# NON-ALCOHOL     3833287    12026      27150.31          26666.38
# REF              159440      505        663.63            388.92
# STR_SUPPLIES     641905     2028       2234.90          10207.66
# WINE          378738407  1210040     746498.59         734618.04
#
#               WAREHOUSE SALES
# ITEM TYPE
# BEER               6527236.51
# DUNNAGE            -121307.00
# KEGS                118431.00
# LIQUOR               94906.27
# NON-ALCOHOL          26149.59
# REF                      0.00
# STR_SUPPLIES             0.00
# WINE               1156984.91

# %%
df[df['WAREHOUSE SALES']<0].head()
# Out:
#       YEAR  MONTH                  SUPPLIER ITEM CODE  \
# 822   2020      1  PREMIUM DISTRIBUTORS INC       175
# 1011  2020      1        ANHEUSER BUSCH INC       205
# 1552  2020      1           FIVE GRAPES LLC    236502
# 2144  2020      1               LEGENDS LTD     25049
# 2305  2020      1    MILLER BREWING COMPANY     26350
#
#                                        ITEM DESCRIPTION ITEM TYPE  \
# 822                               EMPTY 1/2 KEG (30.00)   DUNNAGE
# 1011                              EMPTY 1/6 KEG (30.00)   DUNNAGE
# 1552  J DE TELMONT SANS SOUFRE AJOUTE BRUT CHAMP - 7...      WINE
# 2144                      ERDINGER HEFE WEISSE 50L 1/2K      KEGS
# 2305         LEINENKUGEL SNOW DRIFT VANILLA PRTR 1/2 KG      KEGS
#
#       RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES
# 822            0.0               0.0          -3999.0
# 1011           0.0               0.0           -934.0
# 1552           0.0               0.0             -1.0
# 2144           0.0               0.0             -1.0
# 2305           0.0               0.0             -1.0

# %%
df.groupby('ITEM TYPE').agg({'SUPPLIER': 'first',
                             'YEAR': 'min',
                             'MONTH': 'max',
                             'WAREHOUSE SALES': 'mean'
                            }).reset_index()
# Out:
#       ITEM TYPE                           SUPPLIER  YEAR  MONTH  \
# 0          BEER            RELIABLE CHURCHILL LLLP  2017     12
# 1       DUNNAGE           PREMIUM DISTRIBUTORS INC  2017     12
# 2          KEGS                        LEGENDS LTD  2017     12
# 3        LIQUOR                 JIM BEAM BRANDS CO  2017     12
# 4   NON-ALCOHOL        AMERICAN BEVERAGE MARKETERS  2017     12
# 5           REF                            Default  2017     12
# 6  STR_SUPPLIES                            Default  2017     12
# 7          WINE  REPUBLIC NATIONAL DISTRIBUTING CO  2017     12
#
#    WAREHOUSE SALES
# 0       153.897072
# 1     -1684.819444
# 2        11.672679
# 3         1.462121
# 4        13.770190
# 5         0.000000
# 6         0.000000
# 7         6.165982

# %%
df_item = df.groupby('ITEM TYPE').agg({'SUPPLIER': ['first', 'last'],
                             'YEAR': ['min', 'max'],
                             'MONTH': ['min', 'max'],
                             'WAREHOUSE SALES': ['mean', 'std']
                            }).reset_index()

# %%
df_item.to_excel('item.xlsx')

# %%
df.groupby('ITEM TYPE').sum(numeric_only=True)
# Out:
#                    YEAR    MONTH  RETAIL SALES  RETAIL TRANSFERS  \
# ITEM TYPE
# BEER           85610635   270898     574220.53         566714.00
# DUNNAGE          145332      456          0.00              0.00
# KEGS           20478724    64836          0.00             -1.00
# LIQUOR        131015604   414463     802691.43         794735.71
# NON-ALCOHOL     3833287    12026      27150.31          26666.38
# REF              159440      505        663.63            388.92
# STR_SUPPLIES     641905     2028       2234.90          10207.66
# WINE          378738407  1210040     746498.59         734618.04
#
#               WAREHOUSE SALES
# ITEM TYPE
# BEER               6527236.51
# DUNNAGE            -121307.00
# KEGS                118431.00
# LIQUOR               94906.27
# NON-ALCOHOL          26149.59
# REF                      0.00
# STR_SUPPLIES             0.00
# WINE               1156984.91
